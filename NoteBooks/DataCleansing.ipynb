# %%
import pandas as pd

# %%
csv_data = pd.read_csv('../DataSet/201301_ItemLicitaç╞o.csv', sep=';', encoding='latin-1')

# %%
csv_data.head()
# Out:
#    Código Órgão                Nome Órgão  Código UG  \
# 0         20101  PRESIDENCIA DA REPUBLICA     110001
# 1         20101  PRESIDENCIA DA REPUBLICA     110001
# 2         20101  PRESIDENCIA DA REPUBLICA     110001
# 3         20101  PRESIDENCIA DA REPUBLICA     110001
# 4         20101  PRESIDENCIA DA REPUBLICA     110001
#
#                           Nome UG  Número Licitação   CNPJ Vencedor  \
# 0  SECRETARIA DE ADMINISTRACAO/PR            392012  10359163000119
# 1  SECRETARIA DE ADMINISTRACAO/PR            392012  10359163000119
# 2  SECRETARIA DE ADMINISTRACAO/PR            882012  46049987000130
# 3  SECRETARIA DE ADMINISTRACAO/PR            882012  46049987000130
# 4  SECRETARIA DE ADMINISTRACAO/PR            882012  46049987000130
#
#                                   Nome Vencedor  Número Item  \
# 0         SWOT SERVICO DE FESTAS E EVENTOS LTDA           -1
# 1         SWOT SERVICO DE FESTAS E EVENTOS LTDA           -1
# ...
